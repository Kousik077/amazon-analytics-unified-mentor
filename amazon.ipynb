# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Amazon_Sales_Data.csv ")

# %%
data
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
data['Order Date']=pd.to_datetime(data['Order Date'])
data['month']=data['Order Date'].dt.month

# %%
data['year']=data['Order Date'].dt.year

# %%
print("this graph shows the relationship between units sold on a monthly wise count")
monthly_units_sold=data.groupby('month')['Units Sold'].sum()
plt.figure(figsize=(10,6))
monthly_units_sold.plot(kind='bar')
plt.xlabel('month')
plt.ylabel('Units Sold')
# Out:
# this graph shows the relationship between units sold on a monthly wise count
# Text(0, 0.5, 'Units Sold')

# %%
print("this graph shows the relationship between units sold on a year wise count")
monthly_units_sold=data.groupby('year')['Units Sold'].sum()
plt.figure(figsize=(10,6))
monthly_units_sold.plot(kind='bar')
plt.xlabel('year')
plt.ylabel('Units Sold')
# Out:
# this graph shows the relationship between units sold on a year wise count
# Text(0, 0.5, 'Units Sold')

# %%
df=data.drop_duplicates()

# %%
data
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
data=data.dropna()

# %%
data.to_csv("amazaonsale.csv",index=False)
